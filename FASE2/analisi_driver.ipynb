# %% [markdown]
# ## Query per la dashboard di Analisi dei Driver

# %%
# %run ./00_utility

# %%
catalog = get_catalog()
print("Catalog: ", catalog)

# %%
spark.sql(f"""
SELECT
    id,
    id_scenario,
    new_program_name,
    EXPLODE(shap_values) AS (feature, shap_value)
FROM {catalog}.whatif.webapp_simulations_sostituzione
ORDER BY abs(shap_value) DESC;
""").display()
# Out:
# Databricks visualization. Run in Databricks to view.
